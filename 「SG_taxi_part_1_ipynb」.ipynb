# %% [markdown]
# ##Assessment - Acquire data from the https://data.gov.sg API about the availibilty of SG taxi in a range of time

# %%
import datetime

datetime.datetime.now().strftime("%m/%d/%Y, %H:%M:%S")
# Out:
# '11/01/2023, 05:25:40'

# %%
import datetime


date_time = datetime.datetime.now().strftime("%d/%m/%Y")
date_time
date_list = []
for i in range(10):
  date_list.append(date_time)
  for i in date_list:
    print(type(i))
# date_time_str = datetime.strptime(date_time, "%d/%m/%Y")
# type(date_time_str)



    # date_time = datetime.strptime(date_time_str, "%Y-%m-%dT%H:%M:%S")


    # updated_date_time_str = date_time.strftime("%Y-%m-%dT%H:%M:%S")

    # updated_url = f'https://api.data.gov.sg/v1/transport/taxi-availability?date_time={updated_date_time_str}'


    # date_time = datetime.strptime(date_time_str, "%Y-%m-%dT%H:%M:%S")

    # date_time += timedelta(minutes=30)

    # updated_date_time_str = date_time.strftime("%Y-%m-%dT%H:%M:%S")
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>

# %%
# import libraries

import requests
import pandas as pd

# e.g. you can start by constructing the url for the API for 2022-10-20T05:10:00
url = "https://api.data.gov.sg/v1/transport/taxi-availability"

# %%
# checkpoint 1 - check if you downloaded the data that you want
response = requests.get(url)
response
# Out:
# <Response [200]>

# %%
# Turn received data into JSON (python dict) format

import json

web_data = response.content
py_dict = json.loads(web_data)
py_dict
# Out:
# {'type': 'FeatureCollection',
#  'crs': {'type': 'link',
#   'properties': {'href': 'http://spatialreference.org/ref/epsg/4326/ogcwkt/',
#    'type': 'ogcwkt'}},
#  'features': [{'type': 'Feature',
#    'geometry': {'type': 'MultiPoint',
#     'coordinates': [[103.6567523, 1.31480355],
#      [103.657089383333, 1.32823961666667],
#      [103.65709205, 1.32823975],
#      [103.67847, 1.31],
#      [103.679753, 1.32786783333333],
#      [103.68566405, 1.34073111666667],
#      [103.688499316667, 1.34245126666667],
#      [103.6898285, 1.3425945],
#      [103.69126, 1.34],
#      [103.69349, 1.34],
#      [103.69737, 1.34],
#      [103.69751, 1.35],
#      [103.697962, 1.3472405],
#      [103.698812383333, 1.33791401666667],
#      [103.698822516667, 1.33779073333333],
#      [103.701581333333, 1.33652145],
#      [103.702002683333, 1.34064873333333],
#      [103.70458, 1.34],
#      [103.7072985, 1.344265],
#      [103.711574, 1.343777],
#      [103.713039, 1.345014],
# ...

# %%
print(json.dumps(py_dict, indent=1))
# Out:
# {
#  "type": "FeatureCollection",
#  "crs": {
#   "type": "link",
#   "properties": {
#    "href": "http://spatialreference.org/ref/epsg/4326/ogcwkt/",
#    "type": "ogcwkt"
#   }
#  },
#  "features": [
#   {
#    "type": "Feature",
#    "geometry": {
#     "type": "MultiPoint",
#     "coordinates": [
#      [
#       103.6567523,
#       1.31480355
#      ],
#      [
#       103.657089383333,
#       1.32823961666667
#      ],
#      [
#       103.65709205,
#       1.32823975
#      ],
#      [
#       103.67847,
#       1.31
#      ],
#      [
#       103.679753,
#       1.32786783333333
#      ],
#      [
#       103.68566405,
#       1.34073111666667
#      ],
#      [
#       103.688499316667,
#       1.34245126666667
#      ],
#      [
#       103.6898285,
#       1.3425945
#      ],
#      [
#       103.69126,
#       1.34
#      ],
#      [
#       103.69349,
#       1.34
#      ],
#      [
#       103.69737,
#       1.34
#      ],
#      [
#       103.69751,
#       1.35
# ...

# %%
response_1 = requests.get("https://api.data.gov.sg/v1/transport/taxi-availability?date_time=2022-10-20T10%3A17%3A00")
response_1

dict = response_1.json()
dict
# Out:
# {'type': 'FeatureCollection',
#  'crs': {'type': 'link',
#   'properties': {'href': 'http://spatialreference.org/ref/epsg/4326/ogcwkt/',
#    'type': 'ogcwkt'}},
#  'features': [{'type': 'Feature',
#    'geometry': {'type': 'MultiPoint',
#     'coordinates': [[103.6384, 1.33209],
#      [103.655338, 1.314054],
#      [103.67872, 1.31617],
#      [103.67905, 1.31468],
#      [103.679058433333, 1.32373521666667],
#      [103.68538945, 1.34249341666667],
#      [103.686988366667, 1.34028278333333],
#      [103.6875, 1.34387],
#      [103.688596166667, 1.34308316666667],
#      [103.688853666667, 1.34137966666667],
#      [103.688927, 1.343778],
#      [103.692842333333, 1.3468685],
#      [103.69346, 1.32],
#      [103.69346, 1.34],
#      [103.69698215, 1.3193594],
#      [103.69742, 1.3485],
#      [103.6978, 1.34],
#      [103.697965833333, 1.35527466666667],
#      [103.698, 1.35],
#      [103.6980295, 1.33497783333333],
#      [103.698059983333, 1.35565505],
# ...

# %%
# checkpoint 2 - how many records did you receive?
# Out:
# 1526

# %%
py_dict['features'][0].keys()
# Out:
# dict_keys(['type', 'geometry', 'properties'])

# %%
len(py_dict['features'][0]["geometry"]["coordinates"])
# Out:
# 2374

# %%
# DO you know? -> you can prettify the print out for better readaility with json.dumps

print(json.dumps(py_dict, indent=4))
# Out:
# {
#     "type": "FeatureCollection",
#     "crs": {
#         "type": "link",
#         "properties": {
#             "href": "http://spatialreference.org/ref/epsg/4326/ogcwkt/",
#             "type": "ogcwkt"
#         }
#     },
#     "features": [
#         {
#             "type": "Feature",
#             "geometry": {
#                 "type": "MultiPoint",
#                 "coordinates": [
#                     [
#                         103.62787,
#                         1.28834
#                     ],
#                     [
#                         103.62934,
#                         1.27041
#                     ],
#                     [
#                         103.63922285,
#                         1.32801681666667
#                     ],
#                     [
#                         103.6571324,
#                         1.31374455
#                     ],
#                     [
#                         103.65962,
#                         1.31866
# ...

# %% [markdown]
# # Construct a dataframe with the selected section of the json data, format the df so that we have latitude and longitude as two columns.
#
# Question: why do we need to format our data into this specific format?
#
# ![image.png](data:image/png;base64,...)

# %%
# construct a dataframe with the selected section of the json data

coordinates = dict['features'][0]["geometry"]["coordinates"]
df = pd.DataFrame(coordinates, columns=['Longitude', 'Latitude'])

# 打印前几行数据
print(df.head())
# Out:
#     Longitude  Latitude
# 0  103.638400  1.332090
# 1  103.655338  1.314054
# 2  103.678720  1.316170
# 3  103.679050  1.314680
# 4  103.679058  1.323735

# %%
dict['features'][0]["geometry"]["coordinates"]
# Out:
# [[103.6384, 1.33209],
#  [103.655338, 1.314054],
#  [103.67872, 1.31617],
#  [103.67905, 1.31468],
#  [103.679058433333, 1.32373521666667],
#  [103.68538945, 1.34249341666667],
#  [103.686988366667, 1.34028278333333],
#  [103.6875, 1.34387],
#  [103.688596166667, 1.34308316666667],
#  [103.688853666667, 1.34137966666667],
#  [103.688927, 1.343778],
#  [103.692842333333, 1.3468685],
#  [103.69346, 1.32],
#  [103.69346, 1.34],
#  [103.69698215, 1.3193594],
#  [103.69742, 1.3485],
#  [103.6978, 1.34],
#  [103.697965833333, 1.35527466666667],
#  [103.698, 1.35],
#  [103.6980295, 1.33497783333333],
#  [103.698059983333, 1.35565505],
#  [103.69833, 1.33],
#  [103.69873, 1.35],
#  [103.69907, 1.34],
#  [103.7001, 1.34647],
#  [103.70022, 1.34455],
#  [103.70106, 1.35],
#  [103.7013, 1.34],
#  [103.70162, 1.36],
#  [103.7021978, 1.34460843333333],
#  [103.7025095, 1.33963583333333],
#  [103.702658833333, 1.33753116666667],
#  [103.7033, 1.34095],
#  [103.70404, 1.35],
# ...

# %%
Lot_list = []
Lat_list = []

for Lot in coordinates:
  Lot_list.append(Lot[0])

for Lat in coordinates:
  Lat_list.append(Lot[1])

# %%
# Out:
#            Lot         Lat
# 0     1.326470  103.666240
# 1     1.333926  103.676081
# 2     1.341164  103.688886
# 3     1.341147  103.688887
# 4     1.343048  103.688998
# ...        ...         ...
# 1521  1.390120  103.990370
# 1522  1.358647  103.990530
# 1523  1.360860  103.990560
# 1524  1.360690  103.990610
# 1525  1.358685  103.990920
#
# [1526 rows x 2 columns]

# %%
coordinates = {
    "Lot" : Lot_list,
    "Lat" : Lat_list,
}
df = pd.DataFrame(coordinates)
df
# Out:
#             Lot      Lat
# 0    103.638400  1.37588
# 1    103.655338  1.37588
# 2    103.678720  1.37588
# 3    103.679050  1.37588
# 4    103.679058  1.37588
# ..          ...      ...
# 995  103.988980  1.37588
# 996  103.989285  1.37588
# 997  103.989399  1.37588
# 998  103.989650  1.37588
# 999  104.002543  1.37588
#
# [1000 rows x 2 columns]

# %%
df["Lot"]
# Out:
# 0       103.627220
# 1       103.628550
# 2       103.628590
# 3       103.630090
# 4       103.632750
#            ...
# 1904    103.990110
# 1905    103.990150
# 1906    103.990250
# 1907    103.990870
# 1908    103.995733
# Name: Lot, Length: 1909, dtype: float64

# %%
# checkpoint 3 - test the DF with url from different timestamp
# Out:
#             lat       lot
# 0    103.638400  1.332090
# 1    103.655338  1.314054
# 2    103.678720  1.316170
# 3    103.679050  1.314680
# 4    103.679058  1.323735
# ..          ...       ...
# 995  103.988980  1.359180
# 996  103.989285  1.360668
# 997  103.989399  1.358619
# 998  103.989650  1.357580
# 999  104.002543  1.375880
#
# [1000 rows x 2 columns]

# %%
url_2023_03_20 = "https://api.data.gov.sg/v1/transport/taxi-availability"
new_response = requests.get(url_2023_03_20)
dict_2023_03_20 = response.json()
coordinates_2023_03_20 = py_dict['features'][0]["geometry"]["coordinates"]

Lot_list_1 = []
Lat_list_1 = []

for Lot in coordinates_2023_03_20:
  Lot_list_1.append(Lot[1])

for Lat in coordinates_2023_03_20:
  Lat_list_1.append(Lot[0])

coordinates_dict_1 = {
    "lat" : Lat_list_1,
    "lot" : Lot_list_1,
}
df_1 = pd.DataFrame(coordinates_dict_1)
df_1.head()
# Out:
#           lat      lot
# 0  103.995733  1.31288
# 1  103.995733  1.29805
# 2  103.995733  1.30219
# 3  103.995733  1.30234
# 4  103.995733  1.30064

# %%
df_1.head()
# Out:
#           lat      lot
# 0  103.995733  1.31288
# 1  103.995733  1.29805
# 2  103.995733  1.30219
# 3  103.995733  1.30234
# 4  103.995733  1.30064

# %%
url_2 = "https://api.data.gov.sg/v1/transport/taxi-availability?date_time=2022-10-20T10%3A17%3A00"
new_response = requests.get(url_2)
dict_2 = response.json()
coordinates_2 = py_dict['features'][0]["geometry"]["coordinates"]

Lot_list_2 = []
Lat_list_2 = []

for Lot in coordinates_2:
  Lot_list_2.append(Lot[1])

for Lat in coordinates_2:
  Lat_list_2.append(Lot[0])

coordinates_dict = {
    "lat" : Lat_list_2,
    "lot" : Lot_list_2,
}
df_2 = pd.DataFrame(coordinates_dict)
df_2
# Out:
#              lat       lot
# 0     103.995733  1.312880
# 1     103.995733  1.298050
# 2     103.995733  1.302190
# 3     103.995733  1.302340
# 4     103.995733  1.300640
# ...          ...       ...
# 1904  103.995733  1.358620
# 1905  103.995733  1.358680
# 1906  103.995733  1.358720
# 1907  103.995733  1.360400
# 1908  103.995733  1.389733
#
# [1909 rows x 2 columns]

# %% [markdown]
# #Research about the bokeh library - about how to use it to draw a map with data ontop
# Ask Hammer for an api_key if you need one

# %%
# Out:
#   <div class="bk-root" id="20b9b6aa-413d-4930-906c-a34a3765842d" data-root-id="1558"></div>

# %%
df_1
# Out:
#              lat       lot
# 0     103.995733  1.312880
# 1     103.995733  1.298050
# 2     103.995733  1.302190
# 3     103.995733  1.302340
# 4     103.995733  1.300640
# ...          ...       ...
# 1904  103.995733  1.358620
# 1905  103.995733  1.358680
# 1906  103.995733  1.358720
# 1907  103.995733  1.360400
# 1908  103.995733  1.389733
#
# [1909 rows x 2 columns]

# %%
df
# Out:
#       Longitude  Latitude
# 0    103.638400  1.332090
# 1    103.655338  1.314054
# 2    103.678720  1.316170
# 3    103.679050  1.314680
# 4    103.679058  1.323735
# ..          ...       ...
# 995  103.988980  1.359180
# 996  103.989285  1.360668
# 997  103.989399  1.358619
# 998  103.989650  1.357580
# 999  104.002543  1.375880
#
# [1000 rows x 2 columns]

# %%
# !pip install gmaps
import gmaps
import gmaps.datasets
import pandas as pd
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 8.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 14.7 MB/s eta 0:00:00
# ...
#   Created wheel for gmaps: filename=gmaps-0.9.0-py2.py3-none-any.whl size=2076086 sha256=bfcfdf89ce157bee4d2f6583d21169c00575ac965e4e771ae0541864c3381800
#   Stored in directory: /root/.cache/pip/wheels/b3/c2/dc/48b3ef16c2184dae51a003f17eb5d065bbbf1af3437d9f14e3
# Successfully built gmaps
# ...

# %%
gmaps.configure(api_key="AIzaSyAdPGux9JSUwmSX01FRhUSrwh8SEthxN_0")
locations = df[['Lot', 'Lat']]
fig = gmaps.figure(center=(1.0, 103.0), zoom_level=11)  # 调整中心点和缩放级别

heatmap_layer = gmaps.heatmap_layer(locations)
fig.add_layer(heatmap_layer)

fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# %cd /content/super-gradients
# !pip install .
# Out:
# [Errno 2] No such file or directory: '/content/super-gradients'
# /content
# ERROR: Directory '.' is not installable. Neither 'setup.py' nor 'pyproject.toml' found.

# %%
df
# Out:
#       Longitude  Latitude
# 0    103.638400  1.332090
# 1    103.655338  1.314054
# 2    103.678720  1.316170
# 3    103.679050  1.314680
# 4    103.679058  1.323735
# ..          ...       ...
# 995  103.988980  1.359180
# 996  103.989285  1.360668
# 997  103.989399  1.358619
# 998  103.989650  1.357580
# 999  104.002543  1.375880
#
# [1000 rows x 2 columns]

# %%
import gmaps
import gmaps.datasets
import pandas as pd
from collections.abc import Iterable  # 导入 Iterable
import collections

collections.Iterable = collections.abc.Iterable


# 配置 API 密钥
gmaps.configure(api_key="AIzaSyAdPGux9JSUwmSX01FRhUSrwh8SEthxN_0")


# 创建地图对象
locations = df[['Latitude', 'Longitude']]
fig = gmaps.figure()  # 调整中心点和缩放级别

# 创建散点图层
symbols = gmaps.symbol_layer(
        locations, fill_color='red', stroke_color='red', fill_opacity=0.1)
fig.add_layer(symbols)

fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
from google.colab import output
output.enable_custom_widget_manager()

# %% [markdown]
# Support for third party widgets will remain active for the duration of the session. To disable support:

# %%
from google.colab import output
output.disable_custom_widget_manager()

# %%
data = {
    'lat':[1.288340, 1.270410 , 1.328017, 1.313745, 1.318660],  # 以示例数据为准
    'lon': [103.00796, 103.00796, 103.00796, 103.00796, 103.00796]  # 以示例数据为准
}

# %%
# !pip install bokeh

from bokeh.io import output_notebook, show
from bokeh.models import ColumnDataSource, GMapOptions
from bokeh.plotting import gmap

output_notebook()

# 设置 Google Maps 选项，包括中心点、地图类型和缩放级别
map_options = GMapOptions(lat=1.315, lng=103.685, map_type="roadmap", zoom=12)

# 创建一个 GMap 对象，将 "YOUR_GOOGLE_API_KEY" 替换为您自己的 API 密钥
p = gmap("AIzaSyAdPGux9JSUwmSX01FRhUSrwh8SEthxN_0", map_options, title="Singapore Taxi Map", width=1200, height=800)

source = ColumnDataSource(data=df)


# 在地图上绘制数据点
p.circle(x="Longitude", y="Latitude", size=10, fill_color="red", alpha=0.3, source=source)

# 显示地图和数据
show(p)
# Out:
# ...
#   <div id="e7a789bb-f182-4262-86c1-5fd7bb3b8e42" data-root-id="p1278" style="display: contents;"></div>

# %%
# !pip install bokeh
from bokeh.io import output_notebook, show
from bokeh.models import ColumnDataSource, GMapOptions
from bokeh.plotting import gmap
import pandas as pd

output_notebook()

# 设置 Google Maps 选项，包括中心点、地图类型和缩放级别
map_options = GMapOptions(lat=1.315, lng=103.685, map_type="roadmap", zoom=10)

# 创建一个 GMap 对象，将 "YOUR_GOOGLE_API_KEY" 替换为您自己的 API 密钥
p = gmap("AIzaSyAdPGux9JSUwmSX01FRhUSrwh8SEthxN_0", map_options, title="SG_Taxi")

# 准备包含数据的 Pandas DataFrame（假设您已经读取了数据到 df 变量中）
# 如果您的数据不在 df 中，请根据实际情况修改数据源
data = {
    'Lat': df['Longitude'],
    'Lot': df['Latitude']
}
source = ColumnDataSource(data=data)

# 在地图上绘制数据点
p.circle(x="Lat", y="Lot", size=10, fill_color="red", fill_alpha=0.6, source=source)

# 显示地图和数据
show(p)
# Out:
# ...
#   <div id="cca025c4-d442-4fb9-b56f-41bb86ff48e0" data-root-id="p2088" style="display: contents;"></div>

# %%
# !pip install bokeh

from bokeh.io import output_notebook, show
from bokeh.models import ColumnDataSource, GMapOptions
from bokeh.plotting import gmap

output_notebook()

# 设置 Google Maps 选项，包括中心点、地图类型和缩放级别
map_options = GMapOptions(lat=1.315, lng=103.685, map_type="roadmap", zoom=12)

# 创建一个 GMap 对象，将 "YOUR_GOOGLE_API_KEY" 替换为您自己的 API 密钥
p = gmap("AIzaSyAdPGux9JSUwmSX01FRhUSrwh8SEthxN_0", map_options, title="Singapore Map")

source = ColumnDataSource(data=df_2)


# 在地图上绘制数据点
p.circle(x="lot", y="lat", size=10, fill_color="red", fill_alpha=0.6, source=source)

# 显示地图和数据
show(p)
# Out:
# ...
#   <div id="feb2444c-cdda-42eb-9c3a-ff5e000d3b3e" data-root-id="p1268" style="display: contents;"></div>

# %%
from google.colab import output
output.enable_custom_widget_manager()

# %% [markdown]
# Support for third party widgets will remain active for the duration of the session. To disable support:

# %%
from google.colab import output
output.disable_custom_widget_manager()

# %% [markdown]
# Support for third party widgets will remain active for the duration of the session. To disable support:

# %%
from google.colab import output
output.disable_custom_widget_manager()

# %% [markdown]
# # Acquire the data ofthe entire DEC 2022 and JAN 2023(based on a 30mins interval)
# ### create a folder name 'SG_taxi_data' and save each moment as a separate csv file(you could endup having hundreds of csv files)

# %%
# test to see if we can each 30mins incremental moment - tips using timedelta
# Out:
# datetime.datetime(2022, 12, 1, 1, 30)

# %%
# Hammer Sample for counting time
import time
from datetime import datetime, timedelta


starttime = datetime(2022, 12, 1, 0, 0, 0)
endtime = datetime(2023, 1, 31, 11, 59, 59)

totalIncrement = (endtime - starttime).total_seconds() / 60 / 30
type(totalIncrement)
# Out:
# float

# %%
# Hammer Sampl
from pandas._libs.tslibs.offsets import Minute
index = 0

for i in range(0, int(totalIncrement) + 1):
  if index < 300:
    targetDate = starttime + timedelta(minutes=30)*i
    # print(targetDate)
    print(targetDate.strftime("%Y-%m-%dT%H:%M:%S"))
    print(index)
  index += 1
# Out:
# 2022-12-01T00:00:00
# 0
# 2022-12-01T00:30:00
# 1
# 2022-12-01T01:00:00
# 2
# 2022-12-01T01:30:00
# 3
# 2022-12-01T02:00:00
# 4
# 2022-12-01T02:30:00
# 5
# 2022-12-01T03:00:00
# 6
# 2022-12-01T03:30:00
# 7
# 2022-12-01T04:00:00
# 8
# 2022-12-01T04:30:00
# 9
# 2022-12-01T05:00:00
# 10
# 2022-12-01T05:30:00
# 11
# 2022-12-01T06:00:00
# 12
# 2022-12-01T06:30:00
# 13
# 2022-12-01T07:00:00
# 14
# 2022-12-01T07:30:00
# 15
# 2022-12-01T08:00:00
# 16
# 2022-12-01T08:30:00
# 17
# 2022-12-01T09:00:00
# 18
# 2022-12-01T09:30:00
# 19
# 2022-12-01T10:00:00
# 20
# 2022-12-01T10:30:00
# 21
# 2022-12-01T11:00:00
# 22
# 2022-12-01T11:30:00
# 23
# 2022-12-01T12:00:00
# 24
# 2022-12-01T12:30:00
# 25
# 2022-12-01T13:00:00
# 26
# 2022-12-01T13:30:00
# 27
# 2022-12-01T14:00:00
# 28
# 2022-12-01T14:30:00
# 29
# 2022-12-01T15:00:00
# 30
# 2022-12-01T15:30:00
# 31
# 2022-12-01T16:00:00
# 32
# 2022-12-01T16:30:00
# 33
# 2022-12-01T17:00:00
# 34
# 2022-12-01T17:30:00
# 35
# 2022-12-01T18:00:00
# 36
# ...

# %%
from datetime import datetime

datetime.now() # UTC
datetime.now().strftime("%m-%d-%Y_%H-%M") # datetime obj => string

datetime.strptime('2022-12-1_01-30', "%Y-%m-%d_%H-%M") # string => datetime obj

#datetime.strptime(dt_string, "%d/%m/%Y %H:%M:%S")

date = datetime.strptime(df_26_date_str, '%d_%b_%Y')
# Out:
# datetime.datetime(2022, 12, 1, 1, 30)

# %%
date_time_path = 'https://api.data.gov.sg/v1/transport/taxi-availability?date_time=2022-12-01T00:00:00'
date_time_str = date_time_path.split('?')[-1].split('=')[-1]
date_time = datetime.strptime(date_time_str, "%Y-%m-%dT%H:%M:%S")

type(date_time)

if type(date_time) == "datetime.datetime":
  print("ok")

# %%
df1232 = {"0":[1, 2, 3],
          "1":[1, 2, 3]

}

testdf123 = pd.DataFrame(df1232)
testdf123
# Out:
#    0  1
# 0  1  1
# 1  2  2
# 2  3  3

# %%
df2sdsad =  testdf123.set_axis(['a', 'b'], axis=1)
df2sdsad
# Out:
#    a  b
# 0  1  1
# 1  2  2
# 2  3  3

# %%
from datetime import datetime, timedelta

test_list = []
date_time_path = 'https://api.data.gov.sg/v1/transport/taxi-availability?date_time=2022-12-01T00:00:00'
test_date_time_str = date_time_path.split('?')[-1].split('=')[-1]
test_updated_url = ""
# 將 date_time_str 轉換成時間格式

while True:

  if test_updated_url != 'https://api.data.gov.sg/v1/transport/taxi-availability?date_time=2023-01-31T24:60:00':

    test_date_time = datetime.strptime(test_date_time_str, "%Y-%m-%dT%H:%M:%S")

    test_date_time = test_date_time + timedelta(minutes=30)

    test_updated_date_time_str = test_date_time.strftime("%Y-%m-%dT%H:%M:%S")

    print(test_updated_date_time_str)

    test_updated_url = f'https://api.data.gov.sg/v1/transport/taxi-availability?date_time={test_updated_date_time_str}'

    # print(test_updated_url)

    test_list.append(test_updated_url)
  else:
    break

test_list
# Out:
# 串流輸出內容已截斷至最後 5000 行。
# 2022-12-01T00:30:00
# 2022-12-01T00:30:00
# 2022-12-01T00:30:00
# 2022-12-01T00:30:00
# 2022-12-01T00:30:00
# 2022-12-01T00:30:00
# 2022-12-01T00:30:00
# 2022-12-01T00:30:00
# 2022-12-01T00:30:00
# 2022-12-01T00:30:00
# 2022-12-01T00:30:00
# 2022-12-01T00:30:00
# 2022-12-01T00:30:00
# 2022-12-01T00:30:00
# 2022-12-01T00:30:00
# 2022-12-01T00:30:00
# 2022-12-01T00:30:00
# 2022-12-01T00:30:00
# 2022-12-01T00:30:00
# 2022-12-01T00:30:00
# 2022-12-01T00:30:00
# 2022-12-01T00:30:00
# 2022-12-01T00:30:00
# 2022-12-01T00:30:00
# 2022-12-01T00:30:00
# 2022-12-01T00:30:00
# 2022-12-01T00:30:00
# 2022-12-01T00:30:00
# 2022-12-01T00:30:00
# 2022-12-01T00:30:00
# 2022-12-01T00:30:00
# 2022-12-01T00:30:00
# 2022-12-01T00:30:00
# 2022-12-01T00:30:00
# 2022-12-01T00:30:00
# 2022-12-01T00:30:00
# 2022-12-01T00:30:00
# 2022-12-01T00:30:00
# 2022-12-01T00:30:00
# 2022-12-01T00:30:00
# 2022-12-01T00:30:00
# 2022-12-01T00:30:00
# 2022-12-01T00:30:00
# 2022-12-01T00:30:00
# ...

# %%
from datetime import datetime, timedelta

date_time_list = []
date_time_path = 'https://api.data.gov.sg/v1/transport/taxi-availability?date_time=2022-12-01T00:00:00'
date_time_str = date_time_path.split('?')[-1].split('=')[-1]
updated_url = ""

# index= 0
while updated_url != 'https://api.data.gov.sg/v1/transport/taxi-availability?date_time=2023-01-31T23:30:00':

    date_time = datetime.strptime(date_time_str, "%Y-%m-%dT%H:%M:%S")


    updated_date_time_str = date_time.strftime("%Y-%m-%dT%H:%M:%S")

    updated_url = f'https://api.data.gov.sg/v1/transport/taxi-availability?date_time={updated_date_time_str}'


    date_time = datetime.strptime(date_time_str, "%Y-%m-%dT%H:%M:%S")

    date_time += timedelta(minutes=30)

    updated_date_time_str = date_time.strftime("%Y-%m-%dT%H:%M:%S")

    date_time_str = updated_date_time_str

    # print(date_time_str)

    # print(updated_url)
    date_time_list.append(updated_url)


date_time_list
# Out:
# ['https://api.data.gov.sg/v1/transport/taxi-availability?date_time=2022-12-01T00:00:00',
#  'https://api.data.gov.sg/v1/transport/taxi-availability?date_time=2022-12-01T00:30:00',
#  'https://api.data.gov.sg/v1/transport/taxi-availability?date_time=2022-12-01T01:00:00',
#  'https://api.data.gov.sg/v1/transport/taxi-availability?date_time=2022-12-01T01:30:00',
#  'https://api.data.gov.sg/v1/transport/taxi-availability?date_time=2022-12-01T02:00:00',
#  'https://api.data.gov.sg/v1/transport/taxi-availability?date_time=2022-12-01T02:30:00',
#  'https://api.data.gov.sg/v1/transport/taxi-availability?date_time=2022-12-01T03:00:00',
#  'https://api.data.gov.sg/v1/transport/taxi-availability?date_time=2022-12-01T03:30:00',
#  'https://api.data.gov.sg/v1/transport/taxi-availability?date_time=2022-12-01T04:00:00',
#  'https://api.data.gov.sg/v1/transport/taxi-availability?date_time=2022-12-01T04:30:00',
# ...

# %%
len(date_time_list)
# Out:
# 2976

# %%
import requests
import pandas as pd
for api_url in date_time_list:

# %%
# Out:
# 2022-12-01T00:00:00
# https://api.data.gov.sg/v1/transport/taxi-availability?date_time=2022-12-01T00:00:00
# ----------
#            Lot         Lat
# 0     1.302000  103.628580
# 1     1.334040  103.643190
# 2     1.321770  103.662690
# 3     1.311970  103.669000
# 4     1.325570  103.669370
# ...        ...         ...
# 2026  1.389280  103.998030
# 2027  1.379820  104.001110
# 2028  1.378860  104.001350
# 2029  1.376080  104.002190
# 2030  1.375791  104.002282
#
# [2031 rows x 2 columns]
# 2022-12-01T00:30:00
# https://api.data.gov.sg/v1/transport/taxi-availability?date_time=2022-12-01T00:30:00
# ----------
#            Lot         Lat
# 0     1.340000  103.641960
# 1     1.333890  103.676140
# 2     1.327150  103.679140
# 3     1.315120  103.679250
# 4     1.340562  103.685928
# ...        ...         ...
# 1762  1.361204  103.990862
# 1763  1.380151  104.000999
# 1764  1.380000  104.001040
# 1765  1.384130  104.001150
# 1766  1.374250  104.001930
#
# [1767 rows x 2 columns]
# ...

# %%
# use this command zip all your csv files in the SG_taxi_data folder
# !zip -r '/content/sg_data.zip' '/content/SG_taxi_data/'
# Out:
# updating: content/sg_data/ (stored 0%)
# updating: content/sg_data/2022-12-01T01:00:00.csv (deflated 65%)
# updating: content/sg_data/2022-12-01T00:30:00.csv (deflated 65%)
# updating: content/sg_data/2022-12-01T00:00:00.csv (deflated 65%)

# %% [markdown]
# # Session 2 - Access database from Python
# ### Now you know how to export data into pandas DF as csv, we now want to store data in a DB instead of csv files.
#
# .
#
#
# ## Step 1 - write and store the SG_data Data to a PostgreSQL database.
#
# Research about psycopg2 on
# https://pypi.org/project/psycopg2/ &
# https://www.psycopg.org/docs/
#
# There should be a table named SG_taxi, with lot, lat, date, and time columns
#
# .
#
# ## Step 2 - read the data back from Pandas and load the data into a dataframe called masterDF
#
# load all the taxi data of DEC22 and JAN23, create a master DF that contain all the "moments"
#
# Pay attention to the index of the below screenshot of the result masterDF

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Process the data to obtain insight

# %%
# What time of the day generally has the lowest and highest taxi availabiity?

# %%
#@title
#@markdown Code for concat all the csv into one DF
#unmask it only if you stuck for more than 2 hours
master_df = pd.DataFrame() # Create an empty master DF
for index, i in enumerate(os.listdir('/content/content/taxi_data')): # list out all the file from the unzipped folder(you might have a different path depends on how you put your csv fiels)
    if index < 5: # test with a smaller number of files
        if i.endswith('csv'):
            df = pd.read_csv(os.path.join('/content/content/taxi_data', i))
            df['date'] = i.split('.')[0].split('T')[0]
            df['time'] = i.split('.')[0].split('T')[1]
            # display(df)
            master_df = pd.concat([master_df, df]) # concat the current csv content to the masterDF

master_df

# %% [markdown]
# Extract Year, Month, Day, Hour, Min and Weekday from the date and time columns, (hints - research about pd.to_datetime())

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Checkpoint B2 - Groupby
#
# Now with the time and date data we can groupby the data and turn them into count and average of each hour (  Hint - Research about dataframe.groupby().agg()  )

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Finally, draw a simple bar plot with the data

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Bonus Q2 -   Which areas has the highest Taxi density?

# %% [markdown]
# # Checkpoint B3 - Prepare data
# There are many ways to digest data about areas/locations, this time we would use a more low level way by cutting SG into grids.

# %%
# A quick demo of qcut
# We use it to put data into mutliple "bins"
import pandas as pd

df_demo = pd.DataFrame({'A': list(range(0, 10, 1)), 'B': list(range(0,100, 10))})
df_demo

df_demo['bin'] = pd.qcut(df_demo['B'], q=4, labels=['A', 'B', 'C', 'D'])
df_demo
# Out:
#    A   B bin
# 0  0   0   A
# 1  1  10   A
# 2  2  20   A
# 3  3  30   B
# 4  4  40   B
# 5  5  50   C
# 6  6  60   C
# 7  7  70   D
# 8  8  80   D
# 9  9  90   D

# %% [markdown]
# # Now try to turn SG into a 8 x 8 grid(total 4 sections) and put each taxi's coord into one of the 64 groups.

# %% [markdown]
# ![image.png](data:image/png;base64,...)
